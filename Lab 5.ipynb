# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from mpl_toolkits.mplot3d import Axes3D
import scipy
from scipy import stats
import pickle

infile = open ("higgs_100000_pt_250_500.pkl",'rb')
higgs = pickle.load(infile)

higgs.keys()
# Out:
# Index(['pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1',
#        't2', 't3', 't21', 't32', 'KtDeltaR'],
#       dtype='object')

# %%
#T1 = 1 prong jet, t2 = 2 prong jet. If a 2 prong jet goes from t1 to t2,
#value should increase. Going from 2 to 3, go down a little bit but not much.
#EE2,EE3 represents the ratio of how far particles in the jet.


infile = open ("qcd_100000_pt_250_500.pkl", 'rb')
qcd = pickle.load(infile)

qcd.keys()
# Out:
# Index(['pt', 'eta', 'phi', 'mass', 'ee2', 'ee3', 'd2', 'angularity', 't1',
#        't2', 't3', 't21', 't32', 'KtDeltaR'],
#       dtype='object')

# %%
pt_higgs = higgs['pt']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['pt']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['eta']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['eta']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['phi']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['phi']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['mass']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['mass']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['ee2']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['ee2']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['ee3']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['ee3']
plot = plt.hist(pt_qcd, bins=250, histtype='step')

# %%
pt_higgs = higgs['KtDeltaR']
pt_plot = plt.hist(pt_higgs, bins=250, histtype='step')

pt_qcd = qcd['KtDeltaR']
plot = plt.hist(pt_qcd, bins=250, histtype='step')
